# %% [markdown]
# # Programming Exercise 9
# # Problem #5 Word Frequency

# %%
# I will create a module that counts the number of times a word appears in a text.
# I will start with creating a def function.

def get_words_list(string):
    # I will creat a word list that will split the string.
    word_list=string.split()
    #I will creat a function that will return the word list.
    return word_list

# I will create an empty dictionary that will hold the words that are counted using a def function.

def get_counts(word_list):
    word_counts=dict()
    
    # I will create a for loop to search through the word list.
    for word in word_list:
        # I will use the in function to see if a word is in the word list.
        if not word in word_count:
            word_counts[word]=1
        else:
            word_counts[word]+=1
     # I will create a funtion that will return the word_counts
    return word_counts

# %%
# I will import the module called word counts that I just created.

import wordcount

# %%
# I will create a main function that will open a file.

def main(file_name):
    # I will create a variable that will store string content.
    string_contents=""
    
    # I will create a function that will open and close a file when done.
    with open(file_name, "r") as file:
        # I will create a statement that will store contents of a file as one string.
        string_contents=file.read()
    
    # I will call the word list funtion to get a list of all the words in the string from the file.
    word_list=wordcount.get_words_list(string_contents)
    # I will call the counts funtion to get the word count in the string from the file
    word_counts=wordcount.get_counts(word_list)
    
    # I will create a for loop to count the words and use the print function to print the words.
    for word, count in word_counts.items():
        print(f"{word}:{count}")
        
# I will call the main function to using some text from a document to execute the output.
main("some_text.txt")
# Out:
# Smartphones:3
# Influence:1
# on:7
# Youth:1
# Are:1
# you:8
# aggravated:1
# with:4
# seeing:1
# your:2
# child:1
# constantly:1
# lying:1
# around:2
# their:7
# phones:2
# to:32
# face?:1
# If:1
# so,:1
# are:8
# not:6
# alone.:1
# I:10
# have:9
# twin:1
# girls,:1
# fifteen:1
# years:1
# of:11
# age:1
# and:15
# they:14
# do:9
# just:1
# that,:1
# lie:1
# from:5
# sunup:1
# sundown:1
# looking:1
# at:4
# those:1
# phones.:2
# don't:2
# know:1
# about:2
# you,:1
# but:4
# me:3
# that:6
# is:6
# so:2
# annoying.:1
# When:4
# schools:1
# closed,:1
# activities:1
# were:4
# no:2
# longer:1
# available:1
# for:8
# the:27
# youth,:2
# usage:1
# cellphones:2
# increased.:1
# Parents:2
# oversee:1
# what:2
# our:6
# kids:1
# can:3
# cannot:1
# do;:1
# therefore,:1
# only:2
# be:2
# annoyed:1
# myself.:1
# What:1
# could:2
# possibly:1
# important,:1
# nothing:1
# else:1
# in:9
# world:1
# really:1
# matters?:1
# Well,:1
# least:1
# that's:2
# how:1
# younger:1
# generation:1
# acts.:1
# ...
